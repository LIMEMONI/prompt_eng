# %% [markdown]
# # 웹 스크래퍼 만들기

# %%
# !pip install openai
# !pip install requests
# !pip install bs4
# Out:
# Collecting openai
#   Downloading openai-1.5.0-py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.10.13)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai) (4.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 4.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 openai-1.5.0
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=d099dcabae36b0f2a656f4b5732442f69b7932533c162254e3ec86576b5fc264
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
from openai import OpenAI

client = OpenAI(
    api_key="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"
)

# %% [markdown]
# - 필요한 text만 뽑아오기

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://finance.naver.com/sise/sise_group.naver?type=upjong'

res = requests.get(url)

soup = BeautifulSoup(res.content, 'html.parser')

text = soup.find_all(string=True)

except_tags = ['[document]', 'title', 'noscript', 'header', 'html', 'meta', 'head', 'input','script', 'style']

output = ''
for t in text:
    if t.parent.name not in except_tags:
        output += '{} '.format(t)

print(output)
# Out:
#
#
#
#  메인 메뉴로 바로가기
#  본문으로 바로가기
#
#
#
#
#
#
#
#
#
#
#  네이버
#
#
#
#
#
#  페이
#
#
#
#
#
#
#  증권
#
#
#
#
#
#
#  증권 종목명·지수명 검색
#
#
#
#
#
#
#  검색
#
#  자동완성
#
#
#
#
#
#
#
#  @code@
#  @txt@
#  @market@
#
#  @full_txt@
#  @in_code@
#  @in_name@
#  @in_link@
#  @in_market@
#
#
#
#
#   현재 자동완성 기능을 사용하고 계십니다
#
#
#
#
# 												현재 자동완성 기능을 사용하고 계십니다.
#
#
#
#
#  // 현재 자동완성 기능을 사용하고 계십니다
#   자동완성 기능이 활성화
#
#
#
#
# 												자동완성 기능이 활성화되었습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  증권 홈
#  국내증시 선택됨
#  해외증시
#  시장지표
#  리서치
#  뉴스
#  MY
#
#
#
#
#
#
#
#
#   //  global include
#
#   leftmenu
#
#  국내증시
#
#  주요시세정보
#
#  코스피
#  코스닥
#  선물
#  코스피200
#  코넥스
#  시가총액
#  배당
#  업종
#  테마
#  그룹사
#  ETF
#  ETN
#  상승
#  보합
#  하락
#  상한가
#  하한가
#  급등
#  급락
#  거래상위
#  급증
#  급감
#  투자자별매매동향
#  외국인매매
#  기관매매
#  프로그램매매동향
#  증시자금동향
#  신규상장
#  외국인보유
#  장외시세
#  IPO
#
#
#  투자자보호
#
#  관리종목
#  거래정지종목
#  시장경보종목
#
#
#  종목조건검색
#
#  골든크로스
#  갭상승
#  이격도과열
#  투심과열
#  상대강도과열
#
#
#  기업 전자공시
#  공매도 종합 현황
#
#
#   //leftmenu
#
#   컨텐츠
#
#   로케이터
#
#  증권홈  >  국내증시  >  업종별 시세
#
#  업종별 시세
#   업종별시세
#
#  업종별 전일대비 시세
#
#
#  업종명
#  전일대비
#  전일대비 등락현황
#  등락그래프
#
#
#  전체
#  상승
#  보합
#  하락
#
#
#
#  창업투자
#
#
# 				+3.35%
#
#
#  104
#  78
#  14
#  12
#  100%
#
#
#  항공사
#
#
# 				+3.26%
#
#
#  9
#  8
#  0
#  1
#  97%
#
#
#  제약
#
#
# 				+3.17%
#
#
#  178
#  140
#  11
#  27
#  94%
#
#
#  증권
#
#
# 				+2.97%
#
#
#  38
#  23
#  4
#  11
#  88%
#
#
#  디스플레이패널
#
#
# 				+2.79%
#
#
#  4
#  2
#  2
#  0
#  83%
#
#
#
#
#
#  에너지장비및서비스
#
#
# 				+2.76%
#
#
#  27
#  18
#  4
#  5
#  82%
#
#
#  화장품
#
#
# 				+2.68%
#
#
#  63
#  45
#  3
#  15
#  80%
#
#
#  자동차
#
#
# 				+2.64%
#
#
#  15
#  13
#  1
#  1
#  78%
#
#
#  다각화된통신서비스
#
#
# 				+2.63%
#
#
#  4
#  4
#  0
#  0
#  78%
#
#
#  자동차부품
#
#
# 				+2.59%
#
#
#  151
#  112
#  11
#  28
#  77%
#
#
#
#
#
#  조선
#
#
# 				+2.45%
#
#
#  22
#  21
#  0
#  1
#  73%
#
#
#  은행
#
#
# 				+2.36%
#
#
#  11
#  11
#  0
#  0
#  70%
#
#
#  기계
#
#
# 				+2.18%
#
#
#  100
#  76
#  10
#  14
#  65%
#
#
#  전기제품
#
#
# 				+2.16%
#
#
#  62
#  45
#  7
#  10
#  64%
#
#
#  복합기업
#
#
# 				+2.06%
#
#
#  24
#  17
#  2
#  5
#  61%
#
#
#
#
#
#  운송인프라
#
#
# 				+1.96%
#
#
#  9
#  7
#  0
#  2
#  58%
#
#
#  생명과학도구및서비스
#
#
# 				+1.95%
#
#
#  37
#  27
#  2
#  8
#  58%
#
#
#  가정용기기와용품
#
#
# 				+1.93%
#
#
#  21
#  13
#  4
#  4
#  57%
#
#
#  손해보험
#
#
# 				+1.82%
#
#
#  11
#  10
#  0
#  1
#  54%
#
#
#  전자제품
#
#
# 				+1.65%
#
#
#  19
#  12
#  2
#  5
#  49%
#
#
#
#
#
#  무선통신서비스
#
#
# 				+1.53%
#
#
#  3
#  2
#  0
#  1
#  45%
#
#
#  전기장비
#
#
# 				+1.53%
#
#
#  30
#  23
#  4
#  3
#  45%
#
#
#  생물공학
#
#
# 				+1.50%
#
#
#  61
#  43
#  3
#  15
#  44%
#
#
#  IT서비스
#
#
# 				+1.49%
#
#
#  95
#  63
#  8
#  24
#  44%
#
#
#  석유와가스
#
#
# 				+1.46%
#
#
#  18
#  14
#  3
#  1
#  43%
#
#
#
#
#
#  철강
#
#
# 				+1.40%
#
#
#  57
#  37
#  4
#  16
#  41%
#
#
#  담배
#
#
# 				+1.40%
#
#
#  1
#  1
#  0
#  0
#  41%
#
#
#  종이와목재
#
#
# 				+1.36%
#
#
#  16
#  12
#  3
#  1
#  40%
#
#
#  전자장비와기기
#
#
# 				+1.35%
#
#
#  102
#  66
#  8
#  28
#  40%
#
#
#  전기유틸리티
#
#
# 				+1.32%
#
#
#  4
#  2
#  0
#  2
#  39%
#
#
#
#
#
#  건축제품
#
#
# 				+1.31%
#
#
#  15
#  9
#  0
#  6
#  39%
#
#
#  백화점과일반상점
#
#
# 				+1.25%
#
#
#  15
#  10
#  1
#  4
#  37%
#
#
#  건강관리업체및서비스
#
#
# 				+1.21%
#
#
#  9
#  7
#  0
#  2
#  36%
#
#
#  전문소매
#
#
# 				+1.19%
#
#
#  7
#  4
#  2
#  1
#  35%
#
#
#  식품
#
#
# 				+1.17%
#
#
#  89
#  65
#  3
#  21
#  34%
#
#
#
#
#
#  핸드셋
#
#
# 				+1.17%
#
#
#  66
#  39
#  12
#  15
#  34%
#
#
#  건설
#
#
# 				+1.16%
#
#
#  84
#  43
#  9
#  32
#  34%
#
#
#  상업서비스와공급품
#
#
# 				+1.10%
#
#
#  27
#  19
#  1
#  7
#  32%
#
#
#  통신장비
#
#
# 				+1.06%
#
#
#  49
#  32
#  3
#  14
#  31%
#
#
#  광고
#
#
# 				+0.98%
#
#
#  14
#  13
#  0
#  1
#  29%
#
#
#
#
#
#  건강관리장비와용품
#
#
# 				+0.94%
#
#
#  88
#  54
#  9
#  25
#  28%
#
#
#  양방향미디어와서비스
#
#
# 				+0.89%
#
#
#  17
#  10
#  0
#  7
#  26%
#
#
#  컴퓨터와주변기기
#
#
# 				+0.88%
#
#
#  23
#  16
#  3
#  4
#  26%
#
#
#  생명보험
#
#
# 				+0.87%
#
#
#  4
#  3
#  0
#  1
#  25%
#
#
#  호텔,레스토랑,레저
#
#
# 				+0.86%
#
#
#  17
#  14
#  0
#  3
#  25%
#
#
#
#
#
#  소프트웨어
#
#
# 				+0.84%
#
#
#  74
#  49
#  6
#  19
#  25%
#
#
#  게임엔터테인먼트
#
#
# 				+0.76%
#
#
#  34
#  24
#  1
#  9
#  22%
#
#
#  판매업체
#
#
# 				+0.76%
#
#
#  13
#  7
#  1
#  5
#  22%
#
#
#  섬유,의류,신발,호화품
#
#
# 				+0.76%
#
#
#  85
#  53
#  15
#  17
#  22%
#
#
#  해운사
#
#
# 				+0.75%
#
#
#  10
#  7
#  0
#  3
#  22%
#
#
#
#
#
#  화학
#
#
# 				+0.74%
#
#
#  122
#  85
#  8
#  29
#  22%
#
#
#  교육서비스
#
#
# 				+0.72%
#
#
#  20
#  12
#  3
#  5
#  21%
#
#
#  가스유틸리티
#
#
# 				+0.72%
#
#
#  12
#  9
#  0
#  3
#  21%
#
#
#  비철금속
#
#
# 				+0.70%
#
#
#  42
#  33
#  1
#  8
#  20%
#
#
#  기타
#
#
# 				+0.68%
#
#
#  1190
#  800
#  91
#  299
#  20%
#
#
#
#
#
#  항공화물운송과물류
#
#
# 				+0.66%
#
#
#  14
#  10
#  0
#  4
#  19%
#
#
#  반도체와반도체장비
#
#
# 				+0.63%
#
#
#  159
#  78
#  16
#  65
#  18%
#
#
#  카드
#
#
# 				+0.62%
#
#
#  1
#  1
#  0
#  0
#  18%
#
#
#  건축자재
#
#
# 				+0.59%
#
#
#  47
#  26
#  3
#  18
#  17%
#
#
#  방송과엔터테인먼트
#
#
# 				+0.52%
#
#
#  57
#  41
#  3
#  13
#  15%
#
#
#
#
#
#  문구류
#
#
# 				+0.49%
#
#
#  1
#  1
#  0
#  0
#  14%
#
#
#  식품과기본식료품소매
#
#
# 				+0.44%
#
#
#  9
#  4
#  1
#  4
#  13%
#
#
#  가정용품
#
#
# 				+0.36%
#
#
#  11
#  6
#  1
#  4
#  10%
#
#
#  도로와철도운송
#
#
# 				+0.35%
#
#
#  8
#  5
#  2
#  1
#  10%
#
#
#  음료
#
#
# 				+0.30%
#
#
#  15
#  8
#  2
#  5
#  8%
#
#
#
#
#
#  가구
#
#
# 				+0.27%
#
#
#  11
#  7
#  0
#  4
#  8%
#
#
#  우주항공과국방
#
#
# 				+0.26%
#
#
#  21
#  12
#  4
#  5
#  7%
#
#
#  무역회사와판매업체
#
#
# 				+0.22%
#
#
#  6
#  5
#  0
#  1
#  6%
#
#
#  포장재
#
#
# 				+0.18%
#
#
#  33
#  20
#  2
#  11
#  5%
#
#
#  디스플레이장비및부품
#
#
# 				+0.13%
#
#
#  83
#  40
#  7
#  36
#  3%
#
#
#
#
#
#  기타금융
#
#
# 				+0.08%
#
#
#  6
#  4
#  1
#  1
#  2%
#
#
#  레저용장비와제품
#
#
# 				+0.06%
#
#
#  13
#  8
#  3
#  2
#  1%
#
#
#  다각화된소비자서비스
#
#
# 				-0.19%
#
#
#  1
#  0
#  0
#  1
#  5%
#
#
#  복합유틸리티
#
#
# 				-0.20%
#
#
#  1
#  0
#  0
#  1
#  5%
#
#
#  부동산
#
#
# 				-0.30%
#
#
#  27
#  14
#  4
#  9
#  8%
#
#
#
#
#
#  사무용전자제품
#
#
# 				-0.30%
#
#
#  1
#  0
#  0
#  1
#  8%
#
#
#  출판
#
#
# 				-0.94%
#
#
#  7
#  4
#  0
#  3
#  28%
#
#
#  건강관리기술
#
#
# 				-1.14%
#
#
#  11
#  5
#  1
#  5
#  34%
#
#
#  인터넷과카탈로그소매
#
#
# 				-3.10%
#
#
#  9
#  6
#  1
#  2
#  92%
#
#
#
#
#   //업종별시세
#
#   //컨텐츠
#    right area
#
#
#
#   인기검색어
#
#  더보기
#
#  인기검색어
#
#
#
#  삼성전자
#  78,500
#
#
#
#
#
#
#  한화갤러리아
#  1,358
#
#
#
#
#
#
#  태영건설
#  2,315
#
#
#
#
#
#
#  셀트리온
#  201,500
#
#
#
#
#
#
#  DS단석
#  289,000
#
#
#
#
#
#
#   //인기검색어
#   가장 많이 본 뉴스
#
#  더보기
#
#  주가 ‘반토막’ 한화갤러리아, 매일 산 김동선 부사장 수익률은 -11%
#  태영건설 워크아웃, 금융시장 큰 충격 없어...레고랜드 사태와 달랐다
#  '암호화폐 거물' 비트코인 8천억 매수…통큰 베팅 이유는?
#  "아듀 2023 증시"…외인·기관 '사자'에 따뜻한 마무리
#  ‘워크아웃’ 태영건설, SBS 매각 가능성은…금융위 “대주주 판단”
#
#
#   //가장 많이 본 뉴스
#
#    right area
#
#
#
#
#
#
#  이용약관
#
#
#  개인정보처리방침
#
#
#  게시판 운영원칙
#
#
#  증권 고객센터
#
#
#
# 			네이버파이낸셜(주)이 제공하는 금융 정보는  콘텐츠 제공업체 로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.
# 			네이버파이낸셜(주)과 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.
#
#
#
#
#
#  네이버파이낸셜에 콘텐츠 제공
#
#  에프앤가이드  기업 및 재무정보
#  KG제로인  해외 시세, 시장지표 정보
#  한국예탁결제원  주주총회일, 전자투표 정보
#  인포스탁  국내 테마 정보
#
#
#  네이버에 콘텐츠 제공
#
#  코스콤  국내 시세 정보

# %%
import requests
from bs4 import BeautifulSoup

except_tags = ['[document]', 'title', 'noscript', 'header', 'html', 'meta', 'head', 'input','script', 'style']

# 함수화 시키기
def scrap_web(url: str):
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    text = soup.find_all(string=True)

    text_all = ''
    for t in text:
        if t.parent.name not in except_tags:
            text_all += '{} '.format(t)

    return text_all

# %%
def extract_stock_status(content, temperature=0, max_tokens=2048):
#     user_message = f"""다음은 주가 정보 페이지를 복사해 온 정보야. 다음 정보에서 주가 업종과 시세, 등락 정보를 추출해서 표로 만들어줘.
# {content}
# """
    user_message = f"""다음은 주가 정보 페이지를 복사해 온 정보야. 다음 정보에서 주가 업종과 시세, 등락 정보를 추출해서 JSON 포맷으로 만들어줘. 최상위 10개만 출력해줘.
{content}
"""

    completion = client.chat.completions.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {
                "role": "user",
                "content": user_message
            }
        ],
        temperature=temperature,
        max_tokens=max_tokens,
    )

    return completion.choices[0].message.content

# %%
url = 'https://finance.naver.com/sise/sise_group.naver?type=upjong'

web_text = scrap_web(url)

result = extract_stock_status(web_text)

print(result)
# Out:
# {
#   "주가 업종": [
#     {
#       "업종명": "창업투자",
#       "전일대비": "+3.35%",
#       "전일대비 등락현황": {
#         "상승": 104,
#         "보합": 78,
#         "하락": 14
#       },
#       "등락그래프": 12,
#       "등락비율": "100%"
#     },
#     {
#       "업종명": "항공사",
#       "전일대비": "+3.26%",
#       "전일대비 등락현황": {
#         "상승": 9,
#         "보합": 8,
#         "하락": 0
#       },
#       "등락그래프": 1,
#       "등락비율": "97%"
#     },
#     {
#       "업종명": "제약",
#       "전일대비": "+3.17%",
#       "전일대비 등락현황": {
#         "상승": 178,
#         "보합": 140,
#         "하락": 11
#       },
#       "등락그래프": 27,
#       "등락비율": "94%"
#     },
#     {
#       "업종명": "증권",
#       "전일대비": "+2.97%",
#       "전일대비 등락현황": {
#         "상승": 38,
#         "보합": 23,
#         "하락": 4
#       },
#       "등락그래프": 11,
#       "등락비율": "88%"
#     },
#     {
#       "업종명": "디스플레이패널",
#       "전일대비": "+2.79%",
#       "전일대비 등락현황": {
#         "상승": 4,
#         "보합": 2,
#         "하락": 2
#       },
#       "등락그래프": 0,
#       "등락비율": "83%"
#     },
#     {
#       "업종명": "에너지장비및서비스",
#       "전일대비": "+2.76%",
#       "전일대비 등락현황": {
#         "상승": 27,
#         "보합": 18,
#         "하락": 4
#       },
#       "등락그래프": 5,
#       "등락비율": "82%"
#     },
#     {
#       "업종명": "화장품",
#       "전일대비": "+2.68%",
#       "전일대비 등락현황": {
#         "상승": 63,
#         "보합": 45,
#         "하락": 3
#       },
#       "등락그래프": 15,
#       "등락비율": "80%"
#     },
#     {
#       "업종명": "자동차",
#       "전일대비": "+2.64%",
#       "전일대비 등락현황": {
#         "상승": 15,
#         "보합": 13,
#         "하락": 1
#       },
#       "등락그래프": 1,
#       "등락비율": "78%"
#     },
#     {
#       "업종명": "다각화된통신서비스",
#       "전일대비": "+2.63%",
#       "전일대비 등락현황": {
#         "상승": 4,
#         "보합": 4,
#         "하락": 0
#       },
#       "등락그래프": 0,
#       "등락비율": "78%"
#     },
#     {
#       "업종명": "자동차부품",
#       "전일대비": "+2.59%",
#       "전일대비 등락현황": {
#         "상승": 151,
#         "보합": 112,
#         "하락": 11
#       },
#       "등락그래프": 28,
#       "등락비율": "77%"
#     }
#   ]
# }

# %%
import json

json_result = json.loads(result)
    
json_result
# Out:
# {'주가 업종': [{'업종명': '창업투자',
#    '전일대비': '+3.35%',
#    '전일대비 등락현황': {'상승': 104, '보합': 78, '하락': 14},
#    '등락그래프': 12,
#    '등락비율': '100%'},
#   {'업종명': '항공사',
#    '전일대비': '+3.26%',
#    '전일대비 등락현황': {'상승': 9, '보합': 8, '하락': 0},
#    '등락그래프': 1,
#    '등락비율': '97%'},
#   {'업종명': '제약',
#    '전일대비': '+3.17%',
#    '전일대비 등락현황': {'상승': 178, '보합': 140, '하락': 11},
#    '등락그래프': 27,
#    '등락비율': '94%'},
#   {'업종명': '증권',
#    '전일대비': '+2.97%',
#    '전일대비 등락현황': {'상승': 38, '보합': 23, '하락': 4},
#    '등락그래프': 11,
#    '등락비율': '88%'},
#   {'업종명': '디스플레이패널',
#    '전일대비': '+2.79%',
#    '전일대비 등락현황': {'상승': 4, '보합': 2, '하락': 2},
#    '등락그래프': 0,
#    '등락비율': '83%'},
#   {'업종명': '에너지장비및서비스',
#    '전일대비': '+2.76%',
#    '전일대비 등락현황': {'상승': 27, '보합': 18, '하락': 4},
#    '등락그래프': 5,
#    '등락비율': '82%'},
#   {'업종명': '화장품',
#    '전일대비': '+2.68%',
#    '전일대비 등락현황': {'상승': 63, '보합': 45, '하락': 3},
#    '등락그래프': 15,
#    '등락비율': '80%'},
#   {'업종명': '자동차',
#    '전일대비': '+2.64%',
#    '전일대비 등락현황': {'상승': 15, '보합': 13, '하락': 1},
#    '등락그래프': 1,
#    '등락비율': '78%'},
#   {'업종명': '다각화된통신서비스',
#    '전일대비': '+2.63%',
#    '전일대비 등락현황': {'상승': 4, '보합': 4, '하락': 0},
#    '등락그래프': 0,
#    '등락비율': '78%'},
#   {'업종명': '자동차부품',
#    '전일대비': '+2.59%',
#    '전일대비 등락현황': {'상승': 151, '보합': 112, '하락': 11},
#    '등락그래프': 28,
#    '등락비율': '77%'}]}

# %%
import pandas as pd

df = pd.DataFrame(json_result['주가 업종'])
df
# Out:
#          업종명    전일대비                         전일대비 등락현황  등락그래프  등락비율
# 0       창업투자  +3.35%   {'상승': 104, '보합': 78, '하락': 14}     12  100%
# 1        항공사  +3.26%       {'상승': 9, '보합': 8, '하락': 0}      1   97%
# 2         제약  +3.17%  {'상승': 178, '보합': 140, '하락': 11}     27   94%
# 3         증권  +2.97%     {'상승': 38, '보합': 23, '하락': 4}     11   88%
# 4    디스플레이패널  +2.79%       {'상승': 4, '보합': 2, '하락': 2}      0   83%
# 5  에너지장비및서비스  +2.76%     {'상승': 27, '보합': 18, '하락': 4}      5   82%
# 6        화장품  +2.68%     {'상승': 63, '보합': 45, '하락': 3}     15   80%
# 7        자동차  +2.64%     {'상승': 15, '보합': 13, '하락': 1}      1   78%
# 8  다각화된통신서비스  +2.63%       {'상승': 4, '보합': 4, '하락': 0}      0   78%
# 9      자동차부품  +2.59%  {'상승': 151, '보합': 112, '하락': 11}     28   77%

# %% [markdown]
# ## 코드블럭 정리

# %%
url = 'https://finance.naver.com/sise/sise_group.naver?type=upjong'

web_text = scrap_web(url)

result = extract_stock_status(web_text)

json_result = json.loads(result)
    
df = pd.DataFrame(json_result['주가 업종'])
df
# Out:
#          업종명    전일대비                         전일대비 등락현황  등락그래프    시세
# 0       창업투자  +3.35%   {'상승': 104, '보합': 78, '하락': 14}     12  100%
# 1        항공사  +3.26%       {'상승': 9, '보합': 8, '하락': 0}      1   97%
# 2         제약  +3.17%  {'상승': 178, '보합': 140, '하락': 11}     27   94%
# 3         증권  +2.97%     {'상승': 38, '보합': 23, '하락': 4}     11   88%
# 4    디스플레이패널  +2.79%       {'상승': 4, '보합': 2, '하락': 2}      0   83%
# 5  에너지장비및서비스  +2.76%     {'상승': 27, '보합': 18, '하락': 4}      5   82%
# 6        화장품  +2.68%     {'상승': 63, '보합': 45, '하락': 3}     15   80%
# 7        자동차  +2.64%     {'상승': 15, '보합': 13, '하락': 1}      1   78%
# 8  다각화된통신서비스  +2.63%       {'상승': 4, '보합': 4, '하락': 0}      0   78%
# 9      자동차부품  +2.59%  {'상승': 151, '보합': 112, '하락': 11}     28   77%
